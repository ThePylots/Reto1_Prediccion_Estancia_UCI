# %%
import sqlite3 as db
import pandas as pd
import featuretools as ft
import json

import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# Hacer una query SQL
def sql_query(q):
    conn = db.connect('../db/sqlite/eicu_v2_0_1.sqlite3')
    df = pd.read_sql_query(q, conn)
    conn.close()
    
    return df

# Leer todos los CSV
def read_csvs():
    #import os
    #print( os.getcwd())
    datasets = [ 'admissiondrug', 'admissionDx', 'allergy', 'apacheApsVar', 'apachePatientResult', 'apachePredVar', 'carePlanCareProvider', 'carePlanEOL', 'carePlanGeneral',
                 'carePlanGoal', 'carePlanInfectiousDisease', 'customLab', 'diagnosis', 'hospital', 'infusiondrug', 'intakeOutput', 'lab', 'medication', 'microLab', 'note',
                 'nurseAssessment', 'nurseCare', 'nurseCharting', 'pastHistory', 'patient', 'physicalExam', 'respiratoryCare', 'respiratoryCharting', 'treatment', 'vitalAperiodic',
                 'vitalPeriodic']

    dfs = {}

    for ds_name in datasets:
        dfs[ds_name] = pd.read_csv('../db/csv/' + ds_name + '.csv')
    
    return dfs

dfs = read_csvs()
has_dropped_keys = False # Para que no se droppeen cada vez que se ejecuta la celda siguiente
# Out:
# C:\Users\aleja\AppData\Local\Temp\ipykernel_10124\2990043772.py:21: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[ds_name] = pd.read_csv('../db/csv/' + ds_name + '.csv')

# %%
# Dropear IDs de todas las tablas (primera columna)
def drop_keys(dfs):
    for df_key in dfs.keys():
        if df_key not in ('hospital', 'patient'): # No dropear hospitalId o patientUnitStayId
            df = dfs[df_key]
            dfs[df_key] = df.drop(columns=[df.columns.values[0]])

if not has_dropped_keys:
    drop_keys(dfs)
    has_dropped_keys = True

# %%
dfs['medication']
# Out:
#        patientunitstayid  drugorderoffset  drugstartoffset drugivadmixture  \
# 0                 141765              134             1396              No
# 1                 141765                1             -188              No
# 2                 141765              115              856              No
# 3                 141765              114              316              No
# 4                 141765              115              856              No
# ...                  ...              ...              ...             ...
# 75599            3353113             3367             3789              No
# 75600            3353113                2              -55              No
# 75601            3353113                2            -2258              No
# 75602            3353113                2              -86              No
# 75603            3353113                2            -2151              No
#
#       drugordercancelled                                     drugname  \
# 0                     No                 WARFARIN SODIUM 5 MG PO TABS
# 1                     No  5 ML VIAL : DILTIAZEM HCL 25 MG/5ML IV SOLN
# 2                     No                     ASPIRIN EC 81 MG PO TBEC
# 3                     No                  DILTIAZEM HCL 30 MG PO TABS
# 4                     No                      LISINOPRIL 5 MG PO TABS
# ...                  ...                                          ...
# 75599                Yes                                          NaN
# 75600                 No                                          NaN
# 75601                Yes                                    LORAZEPAM
# 75602                Yes                                          NaN
# 75603                Yes                                          NaN
#
#        drughiclseqno  dosage routeadmin frequency loadingdose  prn  \
# 0             2812.0     5 3         PO       NaN         NaN   No
# 1              182.0    15 3         IV  Once PRN         NaN  Yes
# 2             1820.0    81 3         PO     Daily         NaN   No
# 3              182.0    30 3         PO   Q6H SCH         NaN   No
# 4              132.0     5 3         PO     Daily         NaN   No
# ...              ...     ...        ...       ...         ...  ...
# 75599         6249.0  1 EACH  TRANSDERM     DAILY         NaN   No
# 75600        20971.0  100 ML   INTRAVEN      DRIP         NaN   No
# 75601         4846.0  2-4 MG   INTRAVEN       NaN         NaN  Yes
# 75602        23379.0   20 MG  INTRAMUSC  Q4HRSPRN         NaN  Yes
# 75603         6249.0  1 EACH  TRANSDERM     DAILY         NaN   No
#
#        drugstopoffset  gtc
# 0                2739    0
# 1                 171   38
# 2                2739    0
# 3                2739    0
# 4                2428    0
# ...               ...  ...
# 75599               0   97
# 75600            2721   83
# 75601               0   83
# 75602             -65   80
# 75603               0   97
#
# [75604 rows x 14 columns]

# %%
def clean_respiratoryCare(row, df):
    respiratoryCare = row['currenthistoryseqnum']
           
    return  df[df['patientunitstayid']==row['patientunitstayid']]['currenthistoryseqnum'].max()


def clean_dosage(row):
    dosage = row ['dosage']

    m = re.search('\d+', dosage)
    
    try:
        return int(m.group(0))
    except:
        return -1

# %%
# TODO: Parsear dosage con drugname

dfs['medication'] = dfs['medication'].drop(columns=[
    'drugorderoffset', # Irrelevante
    'drugivadmixture', # No parece relevante
    'drugordercancelled', # Irrelevante
    #'drugname', # Muy incompleta y redundante con drughiclseqno
    'loadingdose', # Mucho NULL
    'prn', # ? Redundante con frequency
    'gtc', # ? No parece que tenga relevancia
    'drugstartoffset', # Supongo que el verdadero impacto esta en la medicación no en el momento
    'drugstopoffset' # Supongo que el verdadero impacto esta en la medicación no en el momento
], axis=1)


# Drop filas cuya columna de dosage sea Nan
dfs['medication'].drop(dfs['medication'][dfs['medication']['dosage'] != dfs['medication']['dosage']].index, inplace=True)

dfs['medication']['dosage']                 = dfs['medication'].apply(clean_dosage, axis=1)

# %%
dfs ['medication'].head(50)
# Out:
#     patientunitstayid                                           drugname  \
# 0              141765                       WARFARIN SODIUM 5 MG PO TABS
# 1              141765        5 ML VIAL : DILTIAZEM HCL 25 MG/5ML IV SOLN
# 2              141765                           ASPIRIN EC 81 MG PO TBEC
# 3              141765                        DILTIAZEM HCL 30 MG PO TABS
# 4              141765                            LISINOPRIL 5 MG PO TABS
# 5              143870                           ASPIRIN EC 81 MG PO TBEC
# 6              143870      1 ML  -  DIPHENHYDRAMINE HCL 50 MG/ML IJ SOLN
# 7              143870                  METOPROLOL TARTRATE 25 MG PO TABS
# 8              143870                CLOPIDOGREL BISULFATE 75 MG PO TABS
# 9              143870                                                NaN
# 10             143870        2 ML  -  METOCLOPRAMIDE HCL 5 MG/ML IJ SOLN
# 11             144815       2 ML VIAL : ONDANSETRON HCL 4 MG/2ML IJ SOLN
# 12             145427       2 ML VIAL : ONDANSETRON HCL 4 MG/2ML IJ SOLN
# 13             145427         1 ML  -  HYDROMORPHONE HCL 1 MG/ML IJ SOLN
# 14             145427              ENOXAPARIN SODIUM 40 MG/0.4ML SC SOLN
# 15             145427      1 ML  -  DIPHENHYDRAMINE HCL 50 MG/ML IJ SOLN
# 16             145427                                                NaN
# 17             147307                                                NaN
# 18             147307                             ASPIRIN 325 MG PO TABS
# 20             147307        HYDROCODONE-ACETAMINOPHEN 10-325 MG PO TABS
# 21             147784                                                NaN
# 22             147784                CLOPIDOGREL BISULFATE 75 MG PO TABS
# 23             147784                       ACETAMINOPHEN 500 MG PO TABS
# 24             147784              ENOXAPARIN SODIUM 40 MG/0.4ML SC SOLN
# 29             148611              ENOXAPARIN SODIUM 40 MG/0.4ML SC SOLN
# 30             148611                          VITAMINS/MINERALS PO TABS
# 31             149432              ENOXAPARIN SODIUM 40 MG/0.4ML SC SOLN
# 32             149432                          VITAMINS/MINERALS PO TABS
# 33             149433       2 ML VIAL : ONDANSETRON HCL 4 MG/2ML IJ SOLN
# 34             149713                           ASPIRIN EC 81 MG PO TBEC
# 35             149713                CLOPIDOGREL BISULFATE 75 MG PO TABS
# 36             149713                CLOPIDOGREL BISULFATE 75 MG PO TABS
# 37             149713                                                NaN
# 38             149713                                                NaN
# 39             149713                           ASPIRIN EC 81 MG PO TBEC
# 40             149713                  PANTOPRAZOLE SODIUM 40 MG PO TBEC
# 41             149714  100 ML  -  MAGNESIUM SULFATE IN D5W 10-5 MG/ML...
# 42             149714                       SPIRONOLACTONE 25 MG PO TABS
# 44             149714                             ASPIRIN 325 MG PO TABS
# 45             149714                 MAGNESIUM SULFATE 2 G IN NS PREMIX
# 46             151179  100 ML  -  METRONIDAZOLE IN NACL 5-0.79 MG/ML-...
# 47             151179                            BISACODYL 10 MG RE SUPP
# 48             151179       SENNOSIDES-DOCUSATE SODIUM 8.6-50 MG PO TABS
# 49             151179        2 ML  -  METOCLOPRAMIDE HCL 5 MG/ML IJ SOLN
# 50             151179                            BISACODYL 10 MG RE SUPP
# 51             151179     50 ML FLEX CONT : MAGNESIUM SULFATE 4% IJ SOLN
# 52             151179       SENNOSIDES-DOCUSATE SODIUM 8.6-50 MG PO TABS
# 53             151179  100 ML  -  MAGNESIUM SULFATE IN D5W 10-5 MG/ML...
# 54             151179                                                NaN
# 55             151867              ENOXAPARIN SODIUM 40 MG/0.4ML SC SOLN
#
#     drughiclseqno  dosage routeadmin    frequency
# 0          2812.0       5         PO          NaN
# 1           182.0      15         IV     Once PRN
# 2          1820.0      81         PO        Daily
# 3           182.0      30         PO      Q6H SCH
# 4           132.0       5         PO        Daily
# 5          1820.0      81         PO        Daily
# 6          4480.0      25         IV  Q15 Min PRN
# 7          2102.0      25         PO     Once PRN
# 8         17539.0      75         PO        Daily
# 9          2104.0      25         PO    Q Evening
# 10         2148.0       5         IV      Q6H PRN
# 11        33598.0       4         IV      Q6H PRN
# 12        33598.0       4         IV     Q12H PRN
# 13         1695.0       1         IV      Q3H PRN
# 14            NaN      40         SC         Q24H
# 15         4480.0      25         IV  Q15 Min PRN
# 16         1324.0     240         PO          BID
# 17            NaN      60         PO        Daily
# 18            NaN     325         PO        Daily
# 20            NaN       1         PO      Q6H PRN
# 21            NaN       1         TD        Daily
# 22        17539.0      75         PO        Daily
# 23         1866.0     500         PO      Q6H PRN
# 24            NaN      40         SC         Q24H
# 29            NaN      40         SC        Daily
# 30         1097.0       1         PO        Daily
# 31            NaN      40         SC         Q24H
# 32            NaN       1         PO        Daily
# 33            NaN       4         IV     Once PRN
# 34            NaN      81         PO        Daily
# 35            NaN      75         PO        Daily
# 36            NaN      75         PO        Daily
# 37            NaN      25         PO        Daily
# 38            NaN      40         PO        Daily
# 39            NaN      81         PO        Daily
# 40            NaN      40         PO       BID AC
# 41            NaN       1         IV    Daily PRN
# 42            NaN      25         PO        Daily
# 44            NaN     325         PO      Q6H PRN
# 45            NaN       2         IV    Daily PRN
# 46         8259.0     500         IV      Q6H SCH
# 47            NaN      10         RE    Daily PRN
# 48        21772.0       2         PO    Daily PRN
# 49         2148.0       5         IV      Q6H PRN
# 50            NaN      10         RE    Daily PRN
# 51          610.0       2         IV    Daily PRN
# 52        21772.0       2         PO    Daily PRN
# 53         6306.0       1         IV    Daily PRN
# 54            NaN      10         TU     Once PRN
# 55            NaN      40         SC        Daily

# %%
dfs['medication'].info()
print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66299 entries, 0 to 75603
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientunitstayid  66299 non-null  int64
#  1   drugname           41607 non-null  object
#  2   drughiclseqno      62480 non-null  float64
#  3   dosage             66299 non-null  int64
#  4   routeadmin         66281 non-null  object
#  5   frequency          56263 non-null  object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 3.5+ MB
